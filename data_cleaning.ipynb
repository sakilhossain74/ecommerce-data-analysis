# %%
import pandas as pd

# %%
df = pd.read_excel("raw_data.xlsx")
df.head()
# Out:
#   Order_ID Order_Date Customer_ID Product_ID  Quantity  Price  Total_Sales  \
# 0  ORD0001 2024-11-17     CUST456    PROD019         2   2400         4800
# 1  ORD0002 2024-11-24     CUST382    PROD015         2  55000       110000
# 2  ORD0003 2024-02-26     CUST003    PROD017         1   1500         1500
# 3  ORD0004 2024-02-01     CUST359    PROD003         1  25000        25000
# 4  ORD0005 2024-03-04     CUST090    PROD005         2   1500         3000
#
#   Payment_Mode Order_Status
# 0         Card    Delivered
# 1          UPI    Delivered
# 2         Card    Delivered
# 3          COD    Delivered
# 4          UPI    Delivered

# %%
file = pd.ExcelFile("raw_data.xlsx")
print(file.sheet_names)
# Out:
# ['Table_O', 'Orders', 'Table_C', 'Customers', 'Table_P', 'Products']

# %%
customers = pd.read_excel("raw_data.xlsx", sheet_name="Customers")
orders = pd.read_excel("raw_data.xlsx", sheet_name="Orders")
products = pd.read_excel("raw_data.xlsx", sheet_name="Products")

# %%
orders.head()
# Out:
#   Order_ID Order_Date Customer_ID Product_ID  Quantity  Price  Total_Sales  \
# 0  ORD0001 2024-03-11     CUST199    PROD013         1    700          700
# 1  ORD0002 2024-12-12     CUST243    PROD013         4    700         2800
# 2  ORD0003 2024-10-02     CUST029    PROD006         2   2000         4000
# 3  ORD0004 2024-06-15     CUST010    PROD030         2   2400         4800
# 4  ORD0005 2024-07-07     CUST402    PROD025         2  55000       110000
#
#   Payment_Mode Order_Status
# 0          UPI   Processing
# 1          COD    Delivered
# 2         Card     Returned
# 3          UPI    Delivered
# 4          COD   Processing

# %%
customers.head()
# Out:
#   Customer_ID Customer_Name       City
# 0     CUST001         Priya  Hyderabad
# 1     CUST002          Ravi     Mumbai
# 2     CUST003          Ravi    Chennai
# 3     CUST004         Pooja  Bangalore
# 4     CUST005          Ravi  Hyderabad

# %%
products.head()
# Out:
#   Product_ID Product_Name     Category  Price
# 0    PROD001      Laptop   Electronics  55000
# 1    PROD002       Mobile  Electronics  20000
# 2    PROD003      Tablet   Electronics  25000
# 3    PROD004      Laptop   Electronics  55000
# 4    PROD005  Headphones   Electronics   1500

# %%
customers.info()
orders.info()
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    500 non-null    object
#  1   Customer_Name  500 non-null    object
#  2   City           500 non-null    object
# dtypes: object(3)
# memory usage: 11.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      1000 non-null   object
#  1   Order_Date    1000 non-null   datetime64[ns]
#  2   Customer_ID   1000 non-null   object
#  3   Product_ID    1000 non-null   object
#  4   Quantity      1000 non-null   int64
#  5   Price         1000 non-null   int64
#  6   Total_Sales   1000 non-null   int64
#  7   Payment_Mode  1000 non-null   object
#  8   Order_Status  1000 non-null   object
# ...

# %%
orders.isnull().sum()
# Out:
# Order_ID        0
# Order_Date      0
# Customer_ID     0
# Product_ID      0
# Quantity        0
# Price           0
# Total_Sales     0
# Payment_Mode    0
# Order_Status    0
# dtype: int64

# %%
orders = orders.drop_duplicates()

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders = orders.dropna()

# %%
orders["Order_Date"] = pd.to_datetime(orders["Order_Date"])

# %%
orders["Order_Status"].unique()
# Out:
# array(['Processing', 'Delivered', 'Returned', 'Shipped', 'Cancelled'],
#       dtype=object)

# %%
orders["Payment_Mode"].unique()
# Out:
# array(['UPI', 'COD', 'Card'], dtype=object)

# %%
orders["Total_Sales"] = orders["Quantity"] * orders["Price"]

# %%
orders.describe()
# Out:
#                        Order_Date    Quantity         Price    Total_Sales
# count                        1000  1000.00000   1000.000000    1000.000000
# mean   2024-06-28 02:06:43.200000     2.94700  17994.500000   52876.400000
# min           2024-01-01 00:00:00     1.00000    400.000000     400.000000
# 25%           2024-03-26 18:00:00     2.00000   2000.000000    4500.000000
# 50%           2024-06-29 00:00:00     3.00000  20000.000000   20000.000000
# 75%           2024-09-26 00:00:00     4.00000  25000.000000   90000.000000
# max           2024-12-30 00:00:00     5.00000  55000.000000  275000.000000
# std                           NaN     1.40505  19452.634391   67939.426909

# %%
orders.to_csv("cleaned_orders.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sakil\\OneDrive\\Desktop'

# %%
orders.to_csv("E:\\project\\data\\cleaned_orders.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sakil\\OneDrive\\Desktop'

# %%
import pandas as pd

# %%
customers = pd.read_excel("E:/project/data/raw_data.xlsx", sheet_name="Customers")

# %%
print(customers.head())
# Out:
#   Customer_ID Customer_Name       City
# 0     CUST001         Priya  Hyderabad
# 1     CUST002          Ravi     Mumbai
# 2     CUST003          Ravi    Chennai
# 3     CUST004         Pooja  Bangalore
# 4     CUST005          Ravi  Hyderabad

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    500 non-null    object
#  1   Customer_Name  500 non-null    object
#  2   City           500 non-null    object
# dtypes: object(3)
# memory usage: 11.8+ KB

# %%
customers.isnull().sum()
# Out:
# Customer_ID      0
# Customer_Name    0
# City             0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers = customers.drop_duplicates()

# %%
customers["Customer_ID"].nunique()
# Out:
# 500

# %%
customers["Customer_ID"].count()
# Out:
# np.int64(500)

# %%
customers["Customer_Name"] = customers["Customer_Name"].str.strip()
customers["City"] = customers["City"].str.strip()

# %%
customers["Customer_Name"] = customers["Customer_Name"].str.title()
customers["City"] = customers["City"].str.title()

# %%
customers["City"].unique()
# Out:
# array(['Hyderabad', 'Mumbai', 'Chennai', 'Bangalore', 'Delhi', 'Kolkata',
#        'Pune', 'Ahmedabad'], dtype=object)

# %%
customers.to_csv("E:/project/data/cleaned_customers.csv", index=False)

# %%
products = pd.read_excel("E:/project/data/raw_data.xlsx", sheet_name="Products")

# %%
products.head()
# Out:
#   Product_ID Product_Name     Category  Price
# 0    PROD001      Laptop   Electronics  55000
# 1    PROD002       Mobile  Electronics  20000
# 2    PROD003      Tablet   Electronics  25000
# 3    PROD004      Laptop   Electronics  55000
# 4    PROD005  Headphones   Electronics   1500

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    30 non-null     object
#  1   Product_Name  30 non-null     object
#  2   Category      30 non-null     object
#  3   Price         30 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
products.isnull().sum()
# Out:
# Product_ID      0
# Product_Name    0
# Category        0
# Price           0
# dtype: int64

# %%
products = products.dropna()

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products = products.drop_duplicates()

# %%
products["Product_ID"].nunique()
products["Product_ID"].count()
# Out:
# np.int64(30)

# %%
products["Product_Name"] = products["Product_Name"].str.strip()
products["Category"] = products["Category"].str.strip()

# %%
products["Product_Name"] = products["Product_Name"].str.title()
products["Category"] = products["Category"].str.title()

# %%
products["Category"].unique()
# Out:
# array(['Electronics', 'Clothing'], dtype=object)

# %%
products["Category"].unique()
# Out:
# array(['Electronics', 'Clothing'], dtype=object)

# %%
products = pd.read_excel("E:/project/data/raw_data.xlsx", sheet_name="Products")

# %%
products["Category"].unique()
# Out:
# array(['Electronics', 'Footwear', 'Clothing', 'Accessories'], dtype=object)

# %%
products.describe()
# Out:
#              Price
# count     30.00000
# mean   17680.00000
# std    19693.08298
# min      400.00000
# 25%     2000.00000
# 50%    11200.00000
# 75%    25000.00000
# max    55000.00000

# %%
products.to_csv("E:/project/data/cleaned_products.csv", index=False)

# %%
customers = pd.read_excel("raw_data.xlsx", sheet_name="Customers")
orders = pd.read_excel("raw_data.xlsx", sheet_name="Orders")
products = pd.read_excel("raw_data.xlsx", sheet_name="Products")

# %%
orders["Customer_ID"].isin(customers["Customer_ID"]).all()
# Out:
# np.True_

# %%
orders["Product_ID"].isin(products["Product_ID"]).all()
# Out:
# np.True_

# %%
orders[(orders["Price"] <= 0) | (orders["Quantity"] <= 0)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Product_ID, Quantity, Price, Total_Sales, Payment_Mode, Order_Status]
# Index: []
